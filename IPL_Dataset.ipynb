# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\singh\Downloads\matches - matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
print(df)
type(df)
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head()# it is function use to get the data for preview. bydefault it give 0 to 4 from top of the data frame.
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.tail()# it is function use to get the data for preview. bydefault it give from buttom of the data frame.
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
df.shape # it is not a function or not a methon 
        # it is a attribute --> which show the architecture of data. 
        # it give a tuple in from of row and column.
# Out:
# (636, 18)

# %%
df.info() # info() function is use to take the information of data. 
            # Note --> in pandas always object denoted to --> String.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe() # it provide a methmatical summary of dataFrame
                # it is only used for int datatype.
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df[ ['winner', 'team1','team2']] # if we fetch a perticular data from column so pass the header in df.[[..,..,..,...]] thish type.
df['winner'] # it is a series.
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.iloc[0:20:2] # 0 --> start from 0. 20 --> between 20 and 2 --> all data between 0 to 20 print between gap of 2.
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2    3    2017     Rajkot  2017-04-07                Gujarat Lions
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
# 16  17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 18  19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2         Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
df.iloc[[3,12,1]] # it is use to find only selected rows from data frame.
# Out:
#     id  season    city        date                   team1  \
# 3    4    2017  Indore  2017-04-08  Rising Pune Supergiant
# 12  13    2017  Rajkot  2017-04-14  Rising Pune Supergiant
# 1    2    2017    Pune  2017-04-06          Mumbai Indians
#
#                      team2             toss_winner toss_decision  result  \
# 3          Kings XI Punjab         Kings XI Punjab         field  normal
# 12           Gujarat Lions           Gujarat Lions         field  normal
# 1   Rising Pune Supergiant  Rising Pune Supergiant         field  normal
#
#     dl_applied                  winner  win_by_runs  win_by_wickets  \
# 3            0         Kings XI Punjab            0               6
# 12           0           Gujarat Lions            0               7
# 1            0  Rising Pune Supergiant            0               7
#
#    player_of_match                                    venue         umpire1  \
# 3       GJ Maxwell                   Holkar Cricket Stadium    AK Chaudhary
# ...

# %%
df.iloc[6:10:,[4,5,10]] # by using iloc we can found a particular column from datframe.
                    # [rows:column] -->
# Out:
#                          team1                   team2            winner
# 6        Kolkata Knight Riders          Mumbai Indians    Mumbai Indians
# 7  Royal Challengers Bangalore         Kings XI Punjab   Kings XI Punjab
# 8             Delhi Daredevils  Rising Pune Supergiant  Delhi Daredevils
# 9          Sunrisers Hyderabad          Mumbai Indians    Mumbai Indians

# %% [markdown]
# # Masking :>
# masking is a technique for selectively modifying, filtering, or extracting data from a Series or DataFrame based on a boolean condition. The core mechanism involves creating a boolean array (or "mask") where True indicates positions to be acted upon and False indicates positions to be kept as is.

# %%
df['city'] == 'Hyderabad' #  in this case look in city column if word Hydrabad match  then it return True otherwise return False.as_integer_ratio
                            # it is a boolean series.
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
mask = df['city'] == 'Hyderabad'
df[mask].shape
# Out:
# (49, 18)

# %%
def get_city_match_count(city):# make a function and pass argument according to according to fatch data.
    mask = df['city'] == city # # match data    
    return df[mask] # found the result

# %%
get_city_match_count('Hyderabad')
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
mask1 = df['city'] =='Hyderabad'
mask2 = df['date']>'2010-01-01'

df[mask1 & mask2]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %%
def match_win(city, date, winner):
    mask1 = df['city'] == city
    mask2 = df['date'] > date
    mask3 = df['winner'] == winner
    return df[mask1 & mask2 & mask3]

# %%
match_win("Hyderabad" , "10-01-01", "Sunrisers Hyderabad" )
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 387  388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 404  405    2013  Hyderabad  2013-04-19              Kings XI Punjab
# 422  423    2013  Hyderabad  2013-05-01               Mumbai Indians
# 427  428    2013  Hyderabad  2013-05-04             Delhi Daredevils
# 448  449    2013  Hyderabad  2013-05-17          Sunrisers Hyderabad
# 452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# ...

# %%
df['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
df["winner"].value_counts().plot(kind = 'bar')# value_count use for count data & plot -- > is use for plot grap of this data
# Out:
# <Axes: xlabel='winner'>

# %%
df['winner'].value_counts().head().plot(kind= 'barh')
# Out:
# <Axes: ylabel='winner'>

# %%
df['toss_decision'].value_counts(0).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[['win_by_runs','win_by_wickets']].value_counts().tail().plot(kind='bar')
# Out:
# <Axes: xlabel='win_by_runs,win_by_wickets'>

# %%
df['win_by_runs'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %%
winner_list = df['winner'].value_counts()

# %%
winner_list['Royal Challengers Bangalore']
# Out:
# np.int64(73)

# %%
winner_list.reset_index()# it gives a list of the index in this serise.
# Out:
#                          winner  count
# 0                Mumbai Indians     92
# 1           Chennai Super Kings     79
# 2         Kolkata Knight Riders     77
# 3   Royal Challengers Bangalore     73
# 4               Kings XI Punjab     70
# 5              Rajasthan Royals     63
# 6              Delhi Daredevils     62
# 7           Sunrisers Hyderabad     42
# 8               Deccan Chargers     29
# 9                 Gujarat Lions     13
# 10                Pune Warriors     12
# 11       Rising Pune Supergiant     10
# 12         Kochi Tuskers Kerala      6
# 13      Rising Pune Supergiants      5

# %%
winner_list.values # it gives a list of all values present in a series.
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
df['team1'].value_counts(0)+ df['team2'].value_counts(0)
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %%
df[['team1','team2']].value_counts() # it make a list of Counting Unique Combinations
#Instead of counting individual teams, this code counts the exact combinations of rows across both columns.
# It looks at every single match and tallies up how many times a specific "Team A" played a specific "Team B" in that exact order.
# Out:
# team1                        team2
# Kings XI Punjab              Kolkata Knight Riders          16
# Kolkata Knight Riders        Royal Challengers Bangalore    16
# Mumbai Indians               Delhi Daredevils               15
# Rajasthan Royals             Kolkata Knight Riders          14
# Royal Challengers Bangalore  Kings XI Punjab                13
#                                                             ..
# Rising Pune Supergiant       Gujarat Lions                   1
#                              Kolkata Knight Riders           1
#                              Kings XI Punjab                 1
# Royal Challengers Bangalore  Rising Pune Supergiants         1
# Sunrisers Hyderabad          Rising Pune Supergiant          1
# Name: count, Length: 127, dtype: int64

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
def metches_win(team1, team2):
    mask0 = df['team1'] == team1
    mask01 = df['team2'] == team2
    return df[mask0]+ df[mask01]

# %%
metches_win('Sunrisers Hyderabad' , 'Royal Challengers Bangalore')
# Out:
#          id  season                city                  date  \
# 0       2.0  4034.0  HyderabadHyderabad  2017-04-052017-04-05
# 9       NaN     NaN                 NaN                   NaN
# 16      NaN     NaN                 NaN                   NaN
# 18      NaN     NaN                 NaN                   NaN
# 20      NaN     NaN                 NaN                   NaN
# ..      ...     ...                 ...                   ...
# 627     NaN     NaN                 NaN                   NaN
# 631     NaN     NaN                 NaN                   NaN
# 632     NaN     NaN                 NaN                   NaN
# 633     NaN     NaN                 NaN                   NaN
# 635  1272.0  4032.0  BangaloreBangalore  2016-05-292016-05-29
#
#                                       team1  \
# 0    Sunrisers HyderabadSunrisers Hyderabad
# 9                                       NaN
# 16                                      NaN
# ...

# %%
list_winner=df[['winner','team1','team2']]

# %%
list_winner
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
list_winner
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
list_winner[['team1','team2']].sort_values
# Out:
# <bound method DataFrame.sort_values of                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
# [636 rows x 2 columns]>

# %%
list_winner
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
list_winner.sort_index
# Out:
# <bound method DataFrame.sort_index of                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# ...

# %%
df['winner'].sort_values(ascending= False).tail()
# Out:
# 546    Chennai Super Kings
# 489    Chennai Super Kings
# 300                    NaN
# 545                    NaN
# 570                    NaN
# Name: winner, dtype: object

# %%
df.sort_values('city',ascending= False, inplace= True) # inplace is used when we chengese permenantly in dataFrame.

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
df.sort_values(['city','date'],ascending= [True , False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.drop_duplicates(subset=['city']) # it remove all duplicate values from dataFrame.
# Out:
#       id  season            city        date                        team1  \
# 312  313    2012   Visakhapatnam  2012-04-07          Chennai Super Kings
# 473  474    2014         Sharjah  2014-04-27          Sunrisers Hyderabad
# 498  499    2014          Ranchi  2014-05-18          Chennai Super Kings
# 19    20    2017          Rajkot  2017-04-18  Royal Challengers Bangalore
# 560  561    2015          Raipur  2015-05-09          Sunrisers Hyderabad
# 531  532    2015            Pune  2015-04-18              Kings XI Punjab
# 152  153    2009  Port Elizabeth  2009-05-10               Mumbai Indians
# 219  220    2010          Nagpur  2010-04-12              Deccan Chargers
# 49    50    2017          Mumbai  2017-05-11              Kings XI Punjab
# 212  213    2010         Kolkata  2010-04-07        Kolkata Knight Riders
# 236  237    2011           Kochi  2011-04-09         Kochi Tuskers Kerala
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# ...

# %%
df.drop_duplicates(subset=['city', 'season']).shape ## in this case it perform as a and operatop means it remove those element which sesaon and city are same.
# Out:
# (107, 18)

# %%
df.drop_duplicates('season',keep= 'last').sort_values(['season','winner'],ascending= True)[['season','winner']]
# Out:
#      season                       winner
# 89     2008               Mumbai Indians
# 164    2009             Delhi Daredevils
# 179    2010             Delhi Daredevils
# 301    2011  Royal Challengers Bangalore
# 316    2012        Kolkata Knight Riders
# 451    2013  Royal Challengers Bangalore
# 476    2014          Sunrisers Hyderabad
# 525    2015             Rajasthan Royals
# 635    2016          Sunrisers Hyderabad
# 44     2017        Kolkata Knight Riders

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data = pd.read_csv(r"C:\Users\singh\Downloads\deliveries.csv\deliveries.csv")

# %%
data
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
most_run =data.groupby("batsman")

# %%
most_run

# %%
most_run.size()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Length: 461, dtype: int64

# %%
most_run.sum("batsman_runs").sort_values("batsman_runs",ascending= False)
# Out:
#               match_id  inning   over   ball  is_super_over  wide_runs  \
# batsman
# SK Raina       1079285    4748  32746  12256              3        124
# V Kohli        1304291    5112  33426  12284              2        110
# RG Sharma      1081920    4822  36662  11601              0         66
# G Gambhir      1072760    5510  23650  12313              0        151
# DA Warner      1085379    4258  21153  10188              1        108
# ...                ...     ...    ...    ...            ...        ...
# RR Bhatkal         640       2     40      9              0          0
# M Ashwin           592       2     20      4              0          0
# Abdur Razzak       202       4     38     11              0          0
# IC Pandey          822       4     40      9              0          0
# Sunny Gupta        380       2     16      5              0          0
#
#               bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# batsman
# ...

# %%
most_run['batsman_runs'].sum().sort_values(ascending= False).head(10)
# Out:
# batsman
# SK Raina          4548
# V Kohli           4423
# RG Sharma         4207
# G Gambhir         4132
# DA Warner         4014
# RV Uthappa        3778
# CH Gayle          3651
# S Dhawan          3561
# MS Dhoni          3560
# AB de Villiers    3486
# Name: batsman_runs, dtype: int64

# %%
data
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
def run(batsman_runs):
    four = data['batsman_runs'] == 4
    return data[four]

# %%
run('4').shape[0]
# Out:
# 17033

# %%
def total_six(batsman_runs):
    six = data['batsman_runs'] == 6
    most_six = six
    return data[most_six]

# %%
total_six("6").shape[0]
# Out:
# 6523

# %%
mask = data['batsman_runs'] == 6
hitting_six = data[mask]

# %%
hitting_six.shape[0]
# Out:
# 6523

# %%
hitting_six.groupby('batsman')['batsman_runs'].count().sort_values(ascending= False).head(5)
# Out:
# batsman
# CH Gayle     266
# SK Raina     174
# RG Sharma    173
# DA Warner    160
# V Kohli      160
# Name: batsman_runs, dtype: int64

# %%
masking = data['batsman_runs'] == 3
three_run = data[masking]

# %%
three_run.shape[0]
# Out:
# 509

# %%
three_run.groupby('batsman')['batsman_runs'].count().sort_values(ascending= False)
# Out:
# batsman
# M Vijay            17
# S Dhawan           16
# G Gambhir          15
# AM Rahane          14
# DA Warner          13
#                    ..
# TM Srivastava       1
# UT Khawaja          1
# W Jaffer            1
# Y Venugopal Rao     1
# Yashpal Singh       1
# Name: batsman_runs, Length: 158, dtype: int64

# %%
data
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
VK = data['batsman'] == 'V Kohli'
V_run= data[VK]

# %%
V_run.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %%
def run_score(batsman_name):
    VK = data['batsman'] == batsman_name
    V_run= data[VK]
    return V_run.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).index[0]

# %%
run_score('MS Dhoni')
# Out:
# 'Royal Challengers Bangalore'

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
new = data.merge(df,left_on='match_id', right_on='id')

# %%
print(data.shape)
print(df.shape)
# Out:
# (150460, 21)
# (636, 18)

# %%
new.groupby(['season','batsman'])['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='season',keep='first').sort_values('season')
# Out:
#     season       batsman  batsman_runs
# 10    2008      SE Marsh           616
# 14    2009     ML Hayden           572
# 9     2010  SR Tendulkar           618
# 11    2011      CH Gayle           608
# 2     2012      CH Gayle           733
# 3     2013    MEK Hussey           733
# 6     2014    RV Uthappa           660
# 17    2015     DA Warner           562
# 0     2016       V Kohli           973
# 7     2017     DA Warner           641

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
win_above_40 = df[df['win_by_runs']>40]

# %%
win_above_40
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 465  466    2014        Sharjah  2014-04-22              Kings XI Punjab
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 316  317    2012      Bangalore  2012-04-10        Kolkata Knight Riders
# 556  557    2015      Bangalore  2015-05-06  Royal Challengers Bangalore
# 497  498    2014      Ahmedabad  2014-05-15             Rajasthan Royals
# 457  458    2014      Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 464  465    2014      Abu Dhabi  2014-04-21          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
win_above_40.shape
# Out:
# (69, 18)

# %% [markdown]
# ## To select rows based on a conditional expression, use a condition inside the selection brackets [].

# %% [markdown]
# The condition inside the selection brackets df['win_by_runs']>40 checks for which rows the Age column has a value larger than 40

# %%
df['win_by_runs']>40
# Out:
# 312     True
# 622     True
# 615    False
# 612     True
# 624    False
#        ...
# 466    False
# 468    False
# 469    False
# 474    False
# 476    False
# Name: win_by_runs, Length: 636, dtype: bool

# %% [markdown]
# The output of the conditional expression (>, but also ==, !=, <, <=,… would work) is actually a pandas Series of boolean values (either True or False) with the same number of rows as the original DataFrame. Such a Series of boolean values can be used to filter the DataFrame by putting it in between the selection brackets []. Only rows for which the value is True will be selected.

# %% [markdown]
# We know from before that the original Titanic DataFrame consists of 636 rows x 18 col. Let’s have a look at the number of rows which satisfy the condition by checking the shape attribute of the resulting DataFrame win_above_40:

# %%
win_above_40.shape
# Out:
# (69, 18)

# %%
df
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
# i am intersted to win be 4 and 1 runs
win_by_run = df['win_by_runs'].isin([4 , 5])

# %%
win_by_run
# Out:
# 312    False
# 622    False
# 615     True
# 612    False
# 624    False
#        ...
# 466    False
# 468     True
# 469    False
# 474    False
# 476    False
# Name: win_by_runs, Length: 636, dtype: bool

# %%
win = df[df["win_by_runs"].isin([4,5])]

# %%
win
# Out:
#       id  season           city        date                        team1  \
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 175  176    2010         Mumbai  2010-03-13               Mumbai Indians
# 420  421    2013         Mumbai  2013-04-29               Mumbai Indians
# 566  567    2015         Mumbai  2015-05-14               Mumbai Indians
# 87    88    2008        Kolkata  2008-05-08        Kolkata Knight Riders
# 563  564    2015      Hyderabad  2015-05-11          Sunrisers Hyderabad
# 18    19    2017      Hyderabad  2017-04-17          Sunrisers Hyderabad
# 437  438    2013          Delhi  2013-05-10  Royal Challengers Bangalore
# 384  385    2013          Delhi  2013-04-06             Rajasthan Royals
# 399  400    2013     Chandigarh  2013-04-16              Kings XI Punjab
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
#
# ...

# %%
team_name = df.loc[df['win_by_wickets']>3, ['team1','win_by_wickets']].head()
team_name
# Out:
#                    team1  win_by_wickets
# 528  Sunrisers Hyderabad               6
# 628      Kings XI Punjab               4
# 618       Mumbai Indians               7
# 315      Deccan Chargers               5
# 473  Sunrisers Hyderabad               5

# %% [markdown]
# In this case, a subset of both rows and columns is made in one go and just using selection brackets [] is not sufficient anymore. The loc/iloc operators are required in front of the selection brackets []. When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.

# %% [markdown]
# ## REMEMBER

# %% [markdown]
# When selecting subsets of data, square brackets [] are used.
#
# Inside these square brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# Use loc for label-based selection (using row/column names).
#
# Use iloc for position-based selection (using table positions).
#
# You can assign new values to a selection based on loc/iloc.
